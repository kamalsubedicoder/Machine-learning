# %%
print("Accessing value from file")
# Out:
# Accessing value from file

# %%
import pandas as pd
import numpy as np

# %%
x =open("Data.csv")
for y in x:
    print(y)
# Out:
# product_name,product_price,product_discount,product_image
#
# Chamberlain myQ Smart Garage Door Opener| Wireless & Wi-Fi enabled Garage Hub with Smartphone Control - MYQ-G0301,,,https://c1.neweggimages.com/ProductImageCompressAll300/81-615-011-Z01.jpg
#
# Kwikset SmartCode 888 Z-Wave Deadbolt. Works w/ Amazon Alexa via SmartThings| Wink| or Iris featuring SmartKey in Satin Nickel (98880-004),$64.99 –,,https://c1.neweggimages.com/ProductImageCompressAll300/V17K_1_20200109226336206.jpg
#
# Aladdin Connect WiFi Garage Door Controller by Genie - Retrofit Add-on Unit for Existing Garage Door Opener / Compatible with Amazon Alexa & Google Assistant,$51.99 –,,https://c1.neweggimages.com/ProductImageCompressAll300/AJBFS200618gVnEn.jpg
#
# Ultraloq U-Bolt Pro Bluetooth Enabled Fingerprint and Keypad Smart Deadbolt + Ultraloq Bridge WiFi Adaptor,$199.00 (3 Offers)–,,https://c1.neweggimages.com/ProductImageCompressAll300/ABF3_132096634380022718n95EajO1TT.jpg
#
# ...

# %%
# Out:
# 0
